# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("C:\\Users\\nlatifi\\Downloads\\archive (3)\\E Commerce Dataset.xlsx")

# %%
data.head()
# Out:
#    CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       50001      1     4.0         Mobile Phone         3              6.0
# 1       50002      1     NaN                Phone         1              8.0
# 2       50003      1     NaN                Phone         1             30.0
# 3       50004      1     0.0                Phone         3             15.0
# 4       50005      1     0.0                Phone         1             12.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0           Debit Card  Female             3.0                         3
# 1                  UPI    Male             3.0                         4
# 2           Debit Card    Male             2.0                         4
# 3           Debit Card    Male             2.0                         4
# 4                   CC    Male             NaN                         3
#
#      PreferedOrderCat  SatisfactionScore MaritalStatus  NumberOfAddress  \
# 0  Laptop & Accessory                  2        Single                9
# 1              Mobile                  3        Single                7
# 2              Mobile                  3        Single                6
# 3  Laptop & Accessory                  5        Single                8
# 4              Mobile                  5        Single                3
#
#    Complain  OrderAmountHikeFromlastYear  CouponUsed  OrderCount  \
# 0         1                         11.0         1.0         1.0
# 1         1                         15.0         0.0         1.0
# 2         1                         14.0         0.0         1.0
# 3         0                         23.0         0.0         1.0
# 4         0                         11.0         1.0         1.0
#
#    DaySinceLastOrder  CashbackAmount
# 0                5.0          159.93
# 1                0.0          120.90
# 2                3.0          120.28
# 3                3.0          134.07
# 4                3.0          129.60

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5630 entries, 0 to 5629
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CustomerID                   5630 non-null   int64
#  1   Churn                        5630 non-null   int64
#  2   Tenure                       5366 non-null   float64
#  3   PreferredLoginDevice         5630 non-null   object
#  4   CityTier                     5630 non-null   int64
#  5   WarehouseToHome              5379 non-null   float64
#  6   PreferredPaymentMode         5630 non-null   object
#  7   Gender                       5630 non-null   object
#  8   HourSpendOnApp               5375 non-null   float64
#  9   NumberOfDeviceRegistered     5630 non-null   int64
#  10  PreferedOrderCat             5630 non-null   object
#  11  SatisfactionScore            5630 non-null   int64
#  12  MaritalStatus                5630 non-null   object
#  13  NumberOfAddress              5630 non-null   int64
#  14  Complain                     5630 non-null   int64
#  15  OrderAmountHikeFromlastYear  5365 non-null   float64
#  16  CouponUsed                   5374 non-null   float64
#  17  OrderCount                   5372 non-null   float64
#  18  DaySinceLastOrder            5323 non-null   float64
#  19  CashbackAmount               5630 non-null   float64
# dtypes: float64(8), int64(7), object(5)
# memory usage: 879.8+ KB

# %%
data1 = data.drop(columns = 'CustomerID')

# %%
data1['CityTier'] = data1.CityTier.astype('object')
data1.dtypes
# Out:
# Churn                            int64
# Tenure                         float64
# PreferredLoginDevice            object
# CityTier                        object
# WarehouseToHome                float64
# PreferredPaymentMode            object
# Gender                          object
# HourSpendOnApp                 float64
# NumberOfDeviceRegistered         int64
# PreferedOrderCat                object
# SatisfactionScore                int64
# MaritalStatus                   object
# NumberOfAddress                  int64
# Complain                         int64
# OrderAmountHikeFromlastYear    float64
# CouponUsed                     float64
# OrderCount                     float64
# DaySinceLastOrder              float64
# CashbackAmount                 float64
# dtype: object

# %%
data1['SatisfactionScore'] = data1.SatisfactionScore.astype('object')
data1.dtypes
# Out:
# Churn                            int64
# Tenure                         float64
# PreferredLoginDevice            object
# CityTier                        object
# WarehouseToHome                float64
# PreferredPaymentMode            object
# Gender                          object
# HourSpendOnApp                 float64
# NumberOfDeviceRegistered         int64
# PreferedOrderCat                object
# SatisfactionScore               object
# MaritalStatus                   object
# NumberOfAddress                  int64
# Complain                         int64
# OrderAmountHikeFromlastYear    float64
# CouponUsed                     float64
# OrderCount                     float64
# DaySinceLastOrder              float64
# CashbackAmount                 float64
# dtype: object

# %%
data1.columns
# Out:
# Index(['Churn', 'Tenure', 'PreferredLoginDevice', 'CityTier',
#        'WarehouseToHome', 'PreferredPaymentMode', 'Gender', 'HourSpendOnApp',
#        'NumberOfDeviceRegistered', 'PreferedOrderCat', 'SatisfactionScore',
#        'MaritalStatus', 'NumberOfAddress', 'Complain',
#        'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount',
#        'DaySinceLastOrder', 'CashbackAmount'],
#       dtype='object')

# %%
data1.describe()
# Out:
#              Churn       Tenure  WarehouseToHome  HourSpendOnApp  \
# count  5630.000000  5366.000000      5379.000000     5375.000000
# mean      0.168384    10.189899        15.639896        2.931535
# std       0.374240     8.557241         8.531475        0.721926
# min       0.000000     0.000000         5.000000        0.000000
# 25%       0.000000     2.000000         9.000000        2.000000
# 50%       0.000000     9.000000        14.000000        3.000000
# 75%       0.000000    16.000000        20.000000        3.000000
# max       1.000000    61.000000       127.000000        5.000000
#
#        NumberOfDeviceRegistered  NumberOfAddress     Complain  \
# count               5630.000000      5630.000000  5630.000000
# mean                   3.688988         4.214032     0.284902
# std                    1.023999         2.583586     0.451408
# min                    1.000000         1.000000     0.000000
# 25%                    3.000000         2.000000     0.000000
# 50%                    4.000000         3.000000     0.000000
# 75%                    4.000000         6.000000     1.000000
# max                    6.000000        22.000000     1.000000
#
#        OrderAmountHikeFromlastYear   CouponUsed   OrderCount  \
# count                  5365.000000  5374.000000  5372.000000
# mean                     15.707922     1.751023     3.008004
# std                       3.675485     1.894621     2.939680
# min                      11.000000     0.000000     1.000000
# 25%                      13.000000     1.000000     1.000000
# 50%                      15.000000     1.000000     2.000000
# 75%                      18.000000     2.000000     3.000000
# max                      26.000000    16.000000    16.000000
#
#        DaySinceLastOrder  CashbackAmount
# count        5323.000000     5630.000000
# mean            4.543491      177.223030
# std             3.654433       49.207036
# min             0.000000        0.000000
# 25%             2.000000      145.770000
# 50%             3.000000      163.280000
# 75%             7.000000      196.392500
# max            46.000000      324.990000

# %%
data1.isna().sum()
# Out:
# Churn                            0
# Tenure                         264
# PreferredLoginDevice             0
# CityTier                         0
# WarehouseToHome                251
# PreferredPaymentMode             0
# Gender                           0
# HourSpendOnApp                 255
# NumberOfDeviceRegistered         0
# PreferedOrderCat                 0
# SatisfactionScore                0
# MaritalStatus                    0
# NumberOfAddress                  0
# Complain                         0
# OrderAmountHikeFromlastYear    265
# CouponUsed                     256
# OrderCount                     258
# DaySinceLastOrder              307
# CashbackAmount                   0
# dtype: int64

# %%
m_1 = data1['DaySinceLastOrder'].mean()
m_2 = data1['OrderAmountHikeFromlastYear'].mean()
m_3 = data1['Tenure'].mean()
m_4 = data1['OrderCount'].mean()
m_5 = data1['CouponUsed'].mean()
m_6 = data1['WarehouseToHome'].mean()
m_7 = data1['HourSpendOnApp'].mean()

data1['DaySinceLastOrder'].fillna(m_1, inplace=True)
data1['OrderAmountHikeFromlastYear'].fillna(m_2, inplace=True)
data1['Tenure'].fillna(m_3, inplace=True)
data1['OrderCount'].fillna(m_4, inplace=True)
data1['CouponUsed'].fillna(m_5, inplace=True)
data1['WarehouseToHome'].fillna(m_6, inplace=True)
data1['HourSpendOnApp'].fillna(m_7, inplace=True)

# %%
data1.isna().sum()
# Out:
# Churn                          0
# Tenure                         0
# PreferredLoginDevice           0
# CityTier                       0
# WarehouseToHome                0
# PreferredPaymentMode           0
# Gender                         0
# HourSpendOnApp                 0
# NumberOfDeviceRegistered       0
# PreferedOrderCat               0
# SatisfactionScore              0
# MaritalStatus                  0
# NumberOfAddress                0
# Complain                       0
# OrderAmountHikeFromlastYear    0
# CouponUsed                     0
# OrderCount                     0
# DaySinceLastOrder              0
# CashbackAmount                 0
# dtype: int64

# %%
x=data1[[ 'Tenure', 'PreferredLoginDevice', 'CityTier',
       'WarehouseToHome', 'PreferredPaymentMode', 'Gender', 'HourSpendOnApp',
       'NumberOfDeviceRegistered', 'PreferedOrderCat', 'SatisfactionScore',
       'MaritalStatus', 'NumberOfAddress', 'Complain',
       'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount',
       'DaySinceLastOrder', 'CashbackAmount']]

# %%
x
# Out:
#          Tenure PreferredLoginDevice CityTier  WarehouseToHome  \
# 0      4.000000         Mobile Phone        3              6.0
# 1     10.189899                Phone        1              8.0
# 2     10.189899                Phone        1             30.0
# 3      0.000000                Phone        3             15.0
# 4      0.000000                Phone        1             12.0
# ...         ...                  ...      ...              ...
# 5625  10.000000             Computer        1             30.0
# 5626  13.000000         Mobile Phone        1             13.0
# 5627   1.000000         Mobile Phone        1             11.0
# 5628  23.000000             Computer        3              9.0
# 5629   8.000000         Mobile Phone        1             15.0
#
#      PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0              Debit Card  Female        3.000000                         3
# 1                     UPI    Male        3.000000                         4
# 2              Debit Card    Male        2.000000                         4
# 3              Debit Card    Male        2.000000                         4
# 4                      CC    Male        2.931535                         3
# ...                   ...     ...             ...                       ...
# 5625          Credit Card    Male        3.000000                         2
# 5626          Credit Card    Male        3.000000                         5
# 5627           Debit Card    Male        3.000000                         2
# 5628          Credit Card    Male        4.000000                         5
# 5629          Credit Card    Male        3.000000                         2
#
#         PreferedOrderCat SatisfactionScore MaritalStatus  NumberOfAddress  \
# 0     Laptop & Accessory                 2        Single                9
# 1                 Mobile                 3        Single                7
# 2                 Mobile                 3        Single                6
# 3     Laptop & Accessory                 5        Single                8
# 4                 Mobile                 5        Single                3
# ...                  ...               ...           ...              ...
# 5625  Laptop & Accessory                 1       Married                6
# 5626             Fashion                 5       Married                6
# 5627  Laptop & Accessory                 4       Married                3
# 5628  Laptop & Accessory                 4       Married                4
# 5629  Laptop & Accessory                 3       Married                4
#
#       Complain  OrderAmountHikeFromlastYear  CouponUsed  OrderCount  \
# 0            1                         11.0         1.0         1.0
# 1            1                         15.0         0.0         1.0
# 2            1                         14.0         0.0         1.0
# 3            0                         23.0         0.0         1.0
# 4            0                         11.0         1.0         1.0
# ...        ...                          ...         ...         ...
# 5625         0                         18.0         1.0         2.0
# 5626         0                         16.0         1.0         2.0
# 5627         1                         21.0         1.0         2.0
# 5628         0                         15.0         2.0         2.0
# 5629         0                         13.0         2.0         2.0
#
#       DaySinceLastOrder  CashbackAmount
# 0              5.000000          159.93
# 1              0.000000          120.90
# 2              3.000000          120.28
# 3              3.000000          134.07
# 4              3.000000          129.60
# ...                 ...             ...
# 5625           4.000000          150.71
# 5626           4.543491          224.91
# 5627           4.000000          186.42
# 5628           9.000000          178.90
# 5629           3.000000          169.04
#
# [5630 rows x 18 columns]

# %%
y = data1[['Churn']]
y
# Out:
#       Churn
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ...     ...
# 5625      0
# 5626      0
# 5627      0
# 5628      0
# 5629      0
#
# [5630 rows x 1 columns]

# %%
x_dum = pd.get_dummies(x)

# %%
x_dum
# Out:
#          Tenure  WarehouseToHome  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0      4.000000              6.0        3.000000                         3
# 1     10.189899              8.0        3.000000                         4
# 2     10.189899             30.0        2.000000                         4
# 3      0.000000             15.0        2.000000                         4
# 4      0.000000             12.0        2.931535                         3
# ...         ...              ...             ...                       ...
# 5625  10.000000             30.0        3.000000                         2
# 5626  13.000000             13.0        3.000000                         5
# 5627   1.000000             11.0        3.000000                         2
# 5628  23.000000              9.0        4.000000                         5
# 5629   8.000000             15.0        3.000000                         2
#
#       NumberOfAddress  Complain  OrderAmountHikeFromlastYear  CouponUsed  \
# 0                   9         1                         11.0         1.0
# 1                   7         1                         15.0         0.0
# 2                   6         1                         14.0         0.0
# 3                   8         0                         23.0         0.0
# 4                   3         0                         11.0         1.0
# ...               ...       ...                          ...         ...
# 5625                6         0                         18.0         1.0
# 5626                6         0                         16.0         1.0
# 5627                3         1                         21.0         1.0
# 5628                4         0                         15.0         2.0
# 5629                4         0                         13.0         2.0
#
#       OrderCount  DaySinceLastOrder  ...  PreferedOrderCat_Mobile Phone  \
# 0            1.0           5.000000  ...                          False
# 1            1.0           0.000000  ...                          False
# 2            1.0           3.000000  ...                          False
# 3            1.0           3.000000  ...                          False
# 4            1.0           3.000000  ...                          False
# ...          ...                ...  ...                            ...
# 5625         2.0           4.000000  ...                          False
# 5626         2.0           4.543491  ...                          False
# 5627         2.0           4.000000  ...                          False
# 5628         2.0           9.000000  ...                          False
# 5629         2.0           3.000000  ...                          False
#
#       PreferedOrderCat_Others  SatisfactionScore_1  SatisfactionScore_2  \
# 0                       False                False                 True
# 1                       False                False                False
# 2                       False                False                False
# 3                       False                False                False
# 4                       False                False                False
# ...                       ...                  ...                  ...
# 5625                    False                 True                False
# 5626                    False                False                False
# 5627                    False                False                False
# 5628                    False                False                False
# 5629                    False                False                False
#
#       SatisfactionScore_3  SatisfactionScore_4  SatisfactionScore_5  \
# 0                   False                False                False
# 1                    True                False                False
# 2                    True                False                False
# 3                   False                False                 True
# 4                   False                False                 True
# ...                   ...                  ...                  ...
# 5625                False                False                False
# 5626                False                False                 True
# 5627                False                 True                False
# 5628                False                 True                False
# 5629                 True                False                False
#
#       MaritalStatus_Divorced  MaritalStatus_Married  MaritalStatus_Single
# 0                      False                  False                  True
# 1                      False                  False                  True
# 2                      False                  False                  True
# 3                      False                  False                  True
# 4                      False                  False                  True
# ...                      ...                    ...                   ...
# 5625                   False                   True                 False
# 5626                   False                   True                 False
# 5627                   False                   True                 False
# 5628                   False                   True                 False
# 5629                   False                   True                 False
#
# [5630 rows x 40 columns]

# %%
x_dum.columns
# Out:
# Index(['Tenure', 'WarehouseToHome', 'HourSpendOnApp',
#        'NumberOfDeviceRegistered', 'NumberOfAddress', 'Complain',
#        'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount',
#        'DaySinceLastOrder', 'CashbackAmount', 'PreferredLoginDevice_Computer',
#        'PreferredLoginDevice_Mobile Phone', 'PreferredLoginDevice_Phone',
#        'CityTier_1', 'CityTier_2', 'CityTier_3', 'PreferredPaymentMode_CC',
#        'PreferredPaymentMode_COD', 'PreferredPaymentMode_Cash on Delivery',
#        'PreferredPaymentMode_Credit Card', 'PreferredPaymentMode_Debit Card',
#        'PreferredPaymentMode_E wallet', 'PreferredPaymentMode_UPI',
#        'Gender_Female', 'Gender_Male', 'PreferedOrderCat_Fashion',
#        'PreferedOrderCat_Grocery', 'PreferedOrderCat_Laptop & Accessory',
#        'PreferedOrderCat_Mobile', 'PreferedOrderCat_Mobile Phone',
#        'PreferedOrderCat_Others', 'SatisfactionScore_1', 'SatisfactionScore_2',
#        'SatisfactionScore_3', 'SatisfactionScore_4', 'SatisfactionScore_5',
#        'MaritalStatus_Divorced', 'MaritalStatus_Married',
#        'MaritalStatus_Single'],
#       dtype='object')

# %%
x_dum.drop(columns=['PreferredLoginDevice_Phone','PreferredPaymentMode_UPI', 'Gender_Male','PreferedOrderCat_Others','MaritalStatus_Single','CityTier_3','SatisfactionScore_5'], axis = 1, inplace=True)

# %%
x_dum.columns
# Out:
# Index(['Tenure', 'WarehouseToHome', 'HourSpendOnApp',
#        'NumberOfDeviceRegistered', 'NumberOfAddress', 'Complain',
#        'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount',
#        'DaySinceLastOrder', 'CashbackAmount', 'PreferredLoginDevice_Computer',
#        'PreferredLoginDevice_Mobile Phone', 'CityTier_1', 'CityTier_2',
#        'PreferredPaymentMode_CC', 'PreferredPaymentMode_COD',
#        'PreferredPaymentMode_Cash on Delivery',
#        'PreferredPaymentMode_Credit Card', 'PreferredPaymentMode_Debit Card',
#        'PreferredPaymentMode_E wallet', 'Gender_Female',
#        'PreferedOrderCat_Fashion', 'PreferedOrderCat_Grocery',
#        'PreferedOrderCat_Laptop & Accessory', 'PreferedOrderCat_Mobile',
#        'PreferedOrderCat_Mobile Phone', 'SatisfactionScore_1',
#        'SatisfactionScore_2', 'SatisfactionScore_3', 'SatisfactionScore_4',
#        'MaritalStatus_Divorced', 'MaritalStatus_Married'],
#       dtype='object')

# %% [markdown]
# ### Assumptions

# %%
import seaborn as sns
sns.pairplot(data,x_vars=['OrderAmountHikeFromlastYear', 'OrderCount',
       'DaySinceLastOrder', 'CashbackAmount']
            ,y_vars=['Churn'],kind='scatter')
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#multi-collinearity test
corr_X1 = x_dum.corr().round(2)

# %%
corr_X1.head()
# Out:
#                           Tenure  WarehouseToHome  HourSpendOnApp  \
# Tenure                      1.00            -0.02           -0.02
# WarehouseToHome            -0.02             1.00            0.06
# HourSpendOnApp             -0.02             0.06            1.00
# NumberOfDeviceRegistered   -0.02             0.02            0.31
# NumberOfAddress             0.23            -0.01            0.14
#
#                           NumberOfDeviceRegistered  NumberOfAddress  Complain  \
# Tenure                                       -0.02             0.23     -0.02
# WarehouseToHome                               0.02            -0.01      0.03
# HourSpendOnApp                                0.31             0.14      0.01
# NumberOfDeviceRegistered                      1.00             0.08      0.00
# NumberOfAddress                               0.08             1.00     -0.03
#
#                           OrderAmountHikeFromlastYear  CouponUsed  OrderCount  \
# Tenure                                           0.00        0.12        0.18
# WarehouseToHome                                  0.04       -0.00        0.00
# HourSpendOnApp                                   0.10        0.18        0.10
# NumberOfDeviceRegistered                         0.07        0.15        0.10
# NumberOfAddress                                  0.02        0.04       -0.01
#
#                           DaySinceLastOrder  ...  PreferedOrderCat_Grocery  \
# Tenure                                 0.18  ...                      0.35
# WarehouseToHome                        0.02  ...                      0.03
# HourSpendOnApp                         0.07  ...                     -0.04
# NumberOfDeviceRegistered               0.02  ...                     -0.04
# NumberOfAddress                       -0.06  ...                      0.07
#
#                           PreferedOrderCat_Laptop & Accessory  \
# Tenure                                                  -0.06
# WarehouseToHome                                          0.04
# HourSpendOnApp                                          -0.04
# NumberOfDeviceRegistered                                -0.01
# NumberOfAddress                                          0.04
#
#                           PreferedOrderCat_Mobile  \
# Tenure                                      -0.16
# WarehouseToHome                             -0.03
# HourSpendOnApp                              -0.19
# NumberOfDeviceRegistered                    -0.22
# NumberOfAddress                             -0.15
#
#                           PreferedOrderCat_Mobile Phone  SatisfactionScore_1  \
# Tenure                                            -0.23                 0.01
# WarehouseToHome                                   -0.02                 0.00
# HourSpendOnApp                                     0.24                -0.01
# NumberOfDeviceRegistered                           0.17                 0.01
# NumberOfAddress                                   -0.03                -0.04
#
#                           SatisfactionScore_2  SatisfactionScore_3  \
# Tenure                                  -0.01                 0.01
# WarehouseToHome                         -0.02                 0.00
# HourSpendOnApp                          -0.02                -0.01
# NumberOfDeviceRegistered                 0.02                -0.00
# NumberOfAddress                         -0.01                -0.01
#
#                           SatisfactionScore_4  MaritalStatus_Divorced  \
# Tenure                                   0.02                    0.04
# WarehouseToHome                          0.00                   -0.01
# HourSpendOnApp                           0.00                    0.01
# NumberOfDeviceRegistered                 0.01                   -0.01
# NumberOfAddress                          0.03                   -0.00
#
#                           MaritalStatus_Married
# Tenure                                     0.08
# WarehouseToHome                            0.03
# HourSpendOnApp                             0.03
# NumberOfDeviceRegistered                  -0.04
# NumberOfAddress                            0.01
#
# [5 rows x 33 columns]

# %%
plt.figure(figsize=(20, 15))
sns.heatmap(corr_X1, annot=True)
plt.show()

# %%
y.value_counts()
# Out:
# Churn
# 0        4682
# 1         948
# Name: count, dtype: int64

# %% [markdown]
# ## Split data

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x_dum,y,test_size=0.2,random_state=0)

# %%
x_train.head()
# Out:
#       Tenure  WarehouseToHome  HourSpendOnApp  NumberOfDeviceRegistered  \
# 1294    15.0             24.0             2.0                         3
# 3904    18.0              9.0             4.0                         2
# 3523     1.0             13.0             3.0                         5
# 2100    18.0             17.0             2.0                         3
# 4481     5.0             14.0             4.0                         4
#
#       NumberOfAddress  Complain  OrderAmountHikeFromlastYear  CouponUsed  \
# 1294                7         1                         17.0    0.000000
# 3904                3         1                         20.0    7.000000
# 3523                3         0                         14.0    3.000000
# 2100                4         0                         13.0    1.751023
# 4481                6         0                         13.0    1.000000
#
#       OrderCount  DaySinceLastOrder  ...  PreferedOrderCat_Grocery  \
# 1294         1.0                2.0  ...                     False
# 3904         7.0                8.0  ...                     False
# 3523         3.0                3.0  ...                     False
# 2100         1.0                1.0  ...                      True
# 4481         2.0                8.0  ...                     False
#
#       PreferedOrderCat_Laptop & Accessory  PreferedOrderCat_Mobile  \
# 1294                                 True                    False
# 3904                                False                    False
# 3523                                False                    False
# 2100                                False                    False
# 4481                                 True                    False
#
#       PreferedOrderCat_Mobile Phone  SatisfactionScore_1  SatisfactionScore_2  \
# 1294                          False                False                False
# 3904                          False                 True                False
# 3523                           True                False                False
# 2100                          False                 True                False
# 4481                          False                 True                False
#
#       SatisfactionScore_3  SatisfactionScore_4  MaritalStatus_Divorced  \
# 1294                False                False                   False
# 3904                False                False                   False
# 3523                 True                False                    True
# 2100                False                False                   False
# 4481                False                False                   False
#
#       MaritalStatus_Married
# 1294                   True
# 3904                   True
# 3523                  False
# 2100                   True
# 4481                   True
#
# [5 rows x 33 columns]

# %%
y_train
# Out:
#       Churn
# 1294      0
# 3904      0
# 3523      0
# 2100      0
# 4481      0
# ...     ...
# 4931      0
# 3264      0
# 1653      0
# 2607      1
# 2732      0
#
# [4504 rows x 1 columns]

# %%
y_train.Churn.value_counts()
# Out:
# Churn
# 0    3743
# 1     761
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
stdscaler=StandardScaler()

# %%
stdscaler.fit(x_train)
# Out:
# StandardScaler()

# %%
x_train_scaled=stdscaler.transform(x_train)

# %%
pd.DataFrame(x_train_scaled).head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.595234  0.993108 -1.303686 -0.662721  1.067950  1.604557  0.354529
# 1  0.957719 -0.795172  1.515699 -1.641376 -0.468561  1.604557  1.191275
# 2 -1.096361 -0.318298  0.106006  1.294588 -0.468561 -0.623225 -0.482216
# 3  0.957719  0.158577 -1.303686 -0.662721 -0.084433 -0.623225 -0.761131
# 4 -0.613048 -0.199079  1.515699  0.315933  0.683822 -0.623225 -0.761131
#
#          7         8         9   ...        23        24       25        26  \
# 0 -0.950393 -0.695799 -0.712343  ... -0.275155  1.313295 -0.40809 -0.544165
# 1  2.893016  1.424175  0.974364  ... -0.275155 -0.761444 -0.40809 -0.544165
# 2  0.696782  0.010859 -0.431225  ... -0.275155 -0.761444 -0.40809  1.837679
# 3  0.011021 -0.695799 -0.993461  ...  3.634309 -0.761444 -0.40809 -0.544165
# 4 -0.401335 -0.342470  0.974364  ... -0.275155  1.313295 -0.40809 -0.544165
#
#          27       28        29        30        31        32
# 0 -0.508036 -0.33604 -0.661860 -0.484057 -0.411047  0.952291
# 1  1.968365 -0.33604 -0.661860 -0.484057 -0.411047  0.952291
# 2 -0.508036 -0.33604  1.510893 -0.484057  2.432815 -1.050099
# 3  1.968365 -0.33604 -0.661860 -0.484057 -0.411047  0.952291
# 4  1.968365 -0.33604 -0.661860 -0.484057 -0.411047  0.952291
#
# [5 rows x 33 columns]

# %%
x_test_scaled=stdscaler.transform(x_test)

# %%
y_train.Churn.value_counts()
# Out:
# Churn
# 0    3743
# 1     761
# Name: count, dtype: int64

# %% [markdown]
# ## Sampling

# %%
from imblearn.over_sampling import SMOTE

# %%
x_resample,y_resample=SMOTE().fit_resample(x_train_scaled,y_train)

# %%
y_resample.Churn.value_counts()
# Out:
# Churn
# 0    3743
# 1    3743
# Name: count, dtype: int64

# %% [markdown]
# ## Logistics Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
logClassifier=LogisticRegression()

# %%
#Training
logClassifier.fit(x_resample,y_resample)
# Out:
# C:\Users\nlatifi\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
logClassifier.score(x_resample,y_resample)
# Out:
# 0.8299492385786802

# %%
#Predict
y_pred=logClassifier.predict(x_test_scaled)

# %%
y_pred
# Out:
# array([1, 0, 0, ..., 0, 1, 1], dtype=int64)

# %%
y_pred_prob = logClassifier.predict_proba(x_test_scaled)

# %%
y_pred_prob
# Out:
# array([[0.068888  , 0.931112  ],
#        [0.8288871 , 0.1711129 ],
#        [0.97748355, 0.02251645],
#        ...,
#        [0.85897523, 0.14102477],
#        [0.38972551, 0.61027449],
#        [0.46177625, 0.53822375]])

# %%
y_pred_prob=pd.DataFrame(y_pred_prob)

# %%
#Evalution
from sklearn.metrics import confusion_matrix

# %%
cm=confusion_matrix(y_test,y_pred)

# %%
print(cm)
# Out:
# [[770 169]
#  [ 51 136]]

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.82      0.88       939
#            1       0.45      0.73      0.55       187
#
#     accuracy                           0.80      1126
#    macro avg       0.69      0.77      0.71      1126
# weighted avg       0.86      0.80      0.82      1126

# %%
from sklearn.metrics import roc_curve

# roc curve for models
fpr1, tpr1, thresh1 = roc_curve(y_test, y_pred_prob.iloc[:,1], pos_label=1)

# %%
random_probs = [0 for i in range(len(y_test))]
p_fpr, p_tpr, _ = roc_curve(y_test, random_probs, pos_label=1)

# %%
from sklearn.metrics import roc_auc_score

# auc scores
auc_score1 = roc_auc_score(y_test, y_pred_prob.iloc[:,1])
print(auc_score1)
# Out:
# 0.8618338999846236

# %%
plt.style.use('seaborn')

# plot roc curves
plt.plot(fpr1, tpr1, linestyle='--',color='orange', label='Logistic Regression')
plt.plot(p_fpr, p_tpr, linestyle='--', color='blue')
# title
plt.title('ROC curve')
# x label
plt.xlabel('False Positive Rate')
# y label
plt.ylabel('True Positive rate')
plt.legend(loc='best')
plt.savefig('ROC',dpi=300)
plt.show();
# Out:
# C:\Users\nlatifi\AppData\Local\Temp\ipykernel_2024\497228701.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
residuals = y_train.values-y_pred
mean_residuals = np.mean(residuals)
print("Mean of Residuals {}".format(mean_residuals))
# Out:
# Mean of Residuals -0.10190941385435169

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 2, metric = 'minkowski', p = 2)
classifier.fit(x_resample, y_resample)
# Out:
# C:\Users\nlatifi\AppData\Roaming\Python\Python311\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier(n_neighbors=2)

# %%
y_pred_knn= classifier.predict(x_test_scaled)

# %%
pd.DataFrame(y_pred)
# Out:
#       0
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
# ...  ..
# 1121  1
# 1122  0
# 1123  0
# 1124  1
# 1125  1
#
# [1126 rows x 1 columns]

# %%
classifier.score(x_resample, y_resample)
# Out:
# 0.999599251936949

# %%
#Evalution
from sklearn.metrics import confusion_matrix

# %%
cm=confusion_matrix(y_test,y_pred_knn)

# %%
cm
# Out:
# array([[899,  40],
#        [ 30, 157]], dtype=int64)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.82      0.88       939
#            1       0.45      0.73      0.55       187
#
#     accuracy                           0.80      1126
#    macro avg       0.69      0.77      0.71      1126
# weighted avg       0.86      0.80      0.82      1126

# %%
from sklearn.datasets import make_blobs

# %%
X, y = make_blobs(n_samples=300, centers=4, cluster_std=0.60, random_state=0)
k_values = list(range(1, 11))
accuracies = []

# %%
for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(x_resample, y_resample)
    accuracy = knn.score(x_test_scaled, y_test)
    accuracies.append(accuracy)
# Out:
# C:\Users\nlatifi\AppData\Roaming\Python\Python311\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\nlatifi\AppData\Roaming\Python\Python311\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\nlatifi\AppData\Roaming\Python\Python311\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\nlatifi\AppData\Roaming\Python\Python311\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\nlatifi\AppData\Roaming\Python\Python311\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\nlatifi\AppData\Roaming\Python\Python311\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\nlatifi\AppData\Roaming\Python\Python311\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\nlatifi\AppData\Roaming\Python\Python311\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\nlatifi\AppData\Roaming\Python\Python311\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\nlatifi\AppData\Roaming\Python\Python311\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
plt.plot(k_values, accuracies, marker='o', linestyle='-')
plt.title('Elbow Method for Optimal K')
plt.xlabel('Number of Neighbors (K)')
plt.ylabel('Accuracy')
plt.xticks(k_values)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
classifier = DecisionTreeClassifier(criterion='gini')

# %%
classifier.fit(x_resample, y_resample)
# Out:
# DecisionTreeClassifier()

# %%
y_pred3 = classifier.predict(x_test_scaled)

# %%
y_pred3
# Out:
# array([0, 0, 1, ..., 0, 1, 0], dtype=int64)

# %%
print('Accuracy on Training Data: ')
classifier.score(x_resample, y_resample)
# Out:
# Accuracy on Training Data:
# 1.0

# %%
print('Accuracy on Test Data: ')
classifier.score(x_test_scaled, y_test)
# Out:
# Accuracy on Test Data:
# 0.9094138543516874

# %%
print('Confusion Matrix: ')
cm3 = confusion_matrix(y_test, y_pred)
cm3
# Out:
# Confusion Matrix:
# array([[770, 169],
#        [ 51, 136]], dtype=int64)

# %%
print("Classification Report: ")
print(classification_report(y_test, y_pred3))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.94       939
#            1       0.70      0.80      0.74       187
#
#     accuracy                           0.91      1126
#    macro avg       0.83      0.86      0.84      1126
# weighted avg       0.92      0.91      0.91      1126

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rclassifier = RandomForestClassifier(n_estimators=10, criterion ='entropy')

# %%
rclassifier.fit(x_resample, y_resample)
# Out:
# C:\Users\nlatifi\AppData\Local\Temp\ipykernel_2024\2593165079.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rclassifier.fit(x_resample, y_resample)
# RandomForestClassifier(criterion='entropy', n_estimators=10)

# %%
y_predi = rclassifier.predict(x_test_scaled)

# %%
print('Accuracy on Training data : ')
rclassifier.score(x_resample, y_resample)
# Out:
# Accuracy on Training data :
# 0.9990649211862143

# %%
rclassifier.feature_importances_
# Out:
# array([0.22230874, 0.04913131, 0.02823735, 0.0560989 , 0.05591307,
#        0.09115993, 0.03820259, 0.03379132, 0.03244492, 0.06244333,
#        0.07211338, 0.01346484, 0.00996022, 0.02047292, 0.00222371,
#        0.00380878, 0.00630344, 0.00226628, 0.01925527, 0.01096062,
#        0.00643808, 0.01738277, 0.00873961, 0.00195912, 0.02779854,
#        0.00575467, 0.00833057, 0.01536794, 0.00764679, 0.01467263,
#        0.01358623, 0.01004909, 0.03171305])

# %%
data.columns
# Out:
# Index(['CustomerID', 'Churn', 'Tenure', 'PreferredLoginDevice', 'CityTier',
#        'WarehouseToHome', 'PreferredPaymentMode', 'Gender', 'HourSpendOnApp',
#        'NumberOfDeviceRegistered', 'PreferedOrderCat', 'SatisfactionScore',
#        'MaritalStatus', 'NumberOfAddress', 'Complain',
#        'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount',
#        'DaySinceLastOrder', 'CashbackAmount'],
#       dtype='object')

# %%
print('Accuracy on Test data: ')
rclassifier.score(x_test_scaled, y_test)
# Out:
# Accuracy on Test data:
# 0.9431616341030196

# %%
print('Confusion Matrix: ')
cm3 = confusion_matrix(y_test, y_predi)
cm3
# Out:
# Confusion Matrix:
# array([[926,  13],
#        [ 51, 136]], dtype=int64)

# %%
from sklearn.metrics import precision_score,accuracy_score
precision_score_list=[precision_score(y_test,y_pred),precision_score(y_test,y_pred_knn),precision_score(y_test,y_pred3),precision_score(y_test,y_predi)]
model_name_list=['LogisticRegression','KNN','DecisionTree(Gini Index)','RandomForest']
 
sns.barplot(x=model_name_list,y=precision_score_list)
plt.xlabel('Model')
plt.ylabel('Precision Score')
plt.title('Precision Scores of Different Models')
plt.ylim(0,1)
plt.xticks(rotation=45)
plt.show()
